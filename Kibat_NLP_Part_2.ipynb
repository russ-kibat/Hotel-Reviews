# %% [markdown]
# # NLP With Hotel Review Part 2
# ## Submitted by Russ Kibat | October 2, 2022
#
# -----
#
# ## Setting up the notebook reviewing the dataset
# ### Libraries

# %%
# Import Libraries 

# data wrangling 
import pandas as pd # dataframe manipulation 
import numpy as np # dependancy for pyplot
import matplotlib.pyplot as plt # create visualizations
from time import time # used to measure run times 
import re # regular expressions 

from sklearn.decomposition import PCA # principal component analysis 
from sklearn.model_selection import train_test_split #data preparation 
from sklearn.preprocessing import StandardScaler # data scaling
from sklearn.metrics import accuracy_score # scoring
from sklearn.model_selection import cross_val_score # scoring
from sklearn.metrics import plot_confusion_matrix # scoring
from sklearn.metrics import classification_report #scoring

# models
from sklearn.linear_model import LogisticRegression 
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
# Load data
test_df = pd.read_csv('data/clean_test_dataframe.csv')
train_df = pd.read_csv('data/clean_train_dataframe.csv')

# %%
# Check the size of the dataframes
print(f'Test data set shape: {test_df.shape[0]} rows {test_df.shape[1]} columns')
print(f'Train data set shape: {train_df.shape[0]} rows {train_df.shape[1]} columns')
# Out:
# Test data set shape: 4267 rows 2744 columns
# Train data set shape: 12798 rows 2744 columns

# %% [markdown]
# ### Data Review

# %%
# take a look all of the columns to get a feel of what the bulk of them are

test_df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4267 entries, 0 to 4266
# Data columns (total 2744 columns):
#  #     Column                                                                   Dtype
# ---    ------                                                                   -----
#  0     Additional_Number_of_Scoring                                             int64
#  1     Average_Score                                                            float64
#  2     Review_Total_Negative_Word_Counts                                        int64
#  3     Total_Number_of_Reviews                                                  int64
#  4     Review_Total_Positive_Word_Counts                                        int64
#  5     Total_Number_of_Reviews_Reviewer_Has_Given                               int64
#  6     days_since_review                                                        int64
#  7     lat                                                                      float64
#  8     lng                                                                      float64
#  9     weekday_of_review                                                        int64
#  10    month_of_review                                                          int64
#  11    year_of_review                                                           int64
#  12    bed_single                                                               int64
#  13    bed_double                                                               int64
#  14    bed_queen                                                                int64
#  15    bed_king                                                                 int64
#  16    trip_leisure                                                             int64
#  17    trip_biz                                                                 int64
#  18    group_solo                                                               int64
#  19    group_couple                                                             int64
#  20    group_family                                                             int64
#  21    Hotel_Name_11 Cadogan Gardens                                            int64
#  22    Hotel_Name_41                                                            int64
#  23    Hotel_Name_88 Studios                                                    int64
#  24    Hotel_Name_Ace Hotel London Shoreditch                                   int64
#  25    Hotel_Name_Adria Boutique Hotel                                          int64
#  26    Hotel_Name_Aloft London Excel                                            int64
#  27    Hotel_Name_Amba Hotel Charing Cross                                      int64
#  28    Hotel_Name_Amba Hotel Marble Arch                                        int64
#  29    Hotel_Name_Ambassadors Bloomsbury                                        int64
#  30    Hotel_Name_Andaz London Liverpool Street                                 int64
#  31    Hotel_Name_Apex City Of London Hotel                                     int64
#  32    Hotel_Name_Apex London Wall Hotel                                        int64
#  33    Hotel_Name_Apex Temple Court Hotel                                       int64
#  34    Hotel_Name_Arbor City                                                    int64
#  35    Hotel_Name_Arbor Hyde Park                                               int64
#  36    Hotel_Name_Ashburn Hotel                                                 int64
#  37    Hotel_Name_Avo Hotel                                                     int64
#  38    Hotel_Name_BEST WESTERN Maitrise Hotel Maida Vale                        int64
#  39    Hotel_Name_Baglioni Hotel London The Leading Hotels of the World         int64
#  40    Hotel_Name_Batty Langley s                                               int64
#  41    Hotel_Name_Bentley London                                                int64
#  42    Hotel_Name_Bermondsey Square Hotel A Bespoke Hotel                       int64
#  43    Hotel_Name_Best Western Maitrise Hotel Edgware Road                      int64
#  44    Hotel_Name_Best Western Mornington Hotel Hyde Park                       int64
#  45    Hotel_Name_Best Western PLUS Epping Forest                               int64
#  46    Hotel_Name_Best Western Palm Hotel                                       int64
#  47    Hotel_Name_Best Western Plus Seraphine Hammersmith Hotel                 int64
#  48    Hotel_Name_Best Western Seraphine Kensington Olympia                     int64
#  49    Hotel_Name_Best Western The Boltons Hotel London Kensington              int64
#  50    Hotel_Name_Blakemore Hyde Park                                           int64
#  51    Hotel_Name_Blakes Hotel                                                  int64
#  52    Hotel_Name_Bloomsbury Palace Hotel                                       int64
#  53    Hotel_Name_Britannia International Hotel Canary Wharf                    int64
#  54    Hotel_Name_Bulgari Hotel London                                          int64
#  55    Hotel_Name_COMO Metropolitan London                                      int64
#  56    Hotel_Name_COMO The Halkin                                               int64
#  57    Hotel_Name_Caesar Hotel                                                  int64
#  58    Hotel_Name_Canary Riverside Plaza Hotel                                  int64
#  59    Hotel_Name_Charlotte Street Hotel                                        int64
#  60    Hotel_Name_Chiswick Rooms                                                int64
#  61    Hotel_Name_Claridge s                                                    int64
#  62    Hotel_Name_Clayton Crown Hotel London                                    int64
#  63    Hotel_Name_Clayton Hotel Chiswick                                        int64
#  64    Hotel_Name_Club Quarters Hotel Gracechurch                               int64
#  65    Hotel_Name_Club Quarters Hotel Lincoln s Inn Fields                      int64
#  66    Hotel_Name_Club Quarters Hotel St Paul s                                 int64
#  67    Hotel_Name_Club Quarters Hotel Trafalgar Square                          int64
#  68    Hotel_Name_Comfort Inn Suites Kings Cross St Pancras                     int64
#  69    Hotel_Name_Commodore Hotel                                               int64
#  70    Hotel_Name_Conrad London St James                                        int64
#  71    Hotel_Name_Copthorne Tara Hotel London Kensington                        int64
#  72    Hotel_Name_Corinthia Hotel London                                        int64
#  73    Hotel_Name_Corus Hotel Hyde Park                                         int64
#  74    Hotel_Name_Courthouse Hotel London                                       int64
#  75    Hotel_Name_Courthouse Hotel Shoreditch                                   int64
#  76    Hotel_Name_Covent Garden Hotel                                           int64
#  77    Hotel_Name_Crowne Plaza London Battersea                                 int64
#  78    Hotel_Name_Crowne Plaza London Docklands                                 int64
#  79    Hotel_Name_Crowne Plaza London Ealing                                    int64
#  80    Hotel_Name_Crowne Plaza London Kensington                                int64
#  81    Hotel_Name_Crowne Plaza London Kings Cross                               int64
#  82    Hotel_Name_Crowne Plaza London The City                                  int64
#  83    Hotel_Name_Danubius Hotel Regents Park                                   int64
#  84    Hotel_Name_De Vere Devonport House                                       int64
#  85    Hotel_Name_Dorset Square Hotel                                           int64
#  86    Hotel_Name_Dorsett Shepherds Bush                                        int64
#  87    Hotel_Name_DoubleTree By Hilton London Excel                             int64
#  88    Hotel_Name_DoubleTree by Hilton Hotel London Marble Arch                 int64
#  89    Hotel_Name_DoubleTree by Hilton Hotel London Tower of London             int64
#  90    Hotel_Name_DoubleTree by Hilton London Chelsea                           int64
#  91    Hotel_Name_DoubleTree by Hilton London Docklands Riverside               int64
#  92    Hotel_Name_DoubleTree by Hilton London Ealing                            int64
#  93    Hotel_Name_DoubleTree by Hilton London Hyde Park                         int64
#  94    Hotel_Name_DoubleTree by Hilton London Islington                         int64
#  95    Hotel_Name_DoubleTree by Hilton London Victoria                          int64
#  96    Hotel_Name_DoubleTree by Hilton London West End                          int64
#  97    Hotel_Name_DoubleTree by Hilton London Westminster                       int64
#  98    Hotel_Name_Doubletree By Hilton London Greenwich                         int64
#  99    Hotel_Name_Doubletree by Hilton London Kensington                        int64
#  100   Hotel_Name_Draycott Hotel                                                int64
#  101   Hotel_Name_Dukes Hotel                                                   int64
#  102   Hotel_Name_Durrants Hotel                                                int64
#  103   Hotel_Name_Eccleston Square Hotel                                        int64
#  104   Hotel_Name_Egerton House                                                 int64
#  105   Hotel_Name_Fielding Hotel                                                int64
#  106   Hotel_Name_Fifty Four Boutique Hotel                                     int64
#  107   Hotel_Name_Flemings Mayfair                                              int64
#  108   Hotel_Name_Four Seasons Hotel London at Park Lane                        int64
#  109   Hotel_Name_Gainsborough Hotel                                            int64
#  110   Hotel_Name_Georgian House Hotel                                          int64
#  111   Hotel_Name_Good Hotel London                                             int64
#  112   Hotel_Name_Goodenough Club                                               int64
#  113   Hotel_Name_Grand Royale London Hyde Park                                 int64
#  114   Hotel_Name_Grange Beauchamp Hotel                                        int64
#  115   Hotel_Name_Grange Blooms Hotel                                           int64
#  116   Hotel_Name_Grange Buckingham Hotel                                       int64
#  117   Hotel_Name_Grange City Hotel                                             int64
#  118   Hotel_Name_Grange Clarendon Hotel                                        int64
#  119   Hotel_Name_Grange Fitzrovia Hotel                                        int64
#  120   Hotel_Name_Grange Holborn Hotel                                          int64
#  121   Hotel_Name_Grange Langham Court Hotel                                    int64
#  122   Hotel_Name_Grange Rochester Hotel                                        int64
#  123   Hotel_Name_Grange St Paul s Hotel                                        int64
#  124   Hotel_Name_Grange Strathmore Hotel                                       int64
#  125   Hotel_Name_Grange Tower Bridge Hotel                                     int64
#  126   Hotel_Name_Grange Wellington Hotel                                       int64
#  127   Hotel_Name_Grange White Hall Hotel                                       int64
#  128   Hotel_Name_Great Northern Hotel A Tribute Portfolio Hotel London         int64
#  129   Hotel_Name_Great St Helen Hotel                                          int64
#  130   Hotel_Name_Grosvenor House A JW Marriott Hotel                           int64
#  131   Hotel_Name_Grosvenor House Suites by Jumeirah Living                     int64
#  132   Hotel_Name_H10 London Waterloo                                           int64
#  133   Hotel_Name_Hallmark Hotel London Chigwell Prince Regent                  int64
#  134   Hotel_Name_Ham Yard Hotel                                                int64
#  135   Hotel_Name_Haymarket Hotel                                               int64
#  136   Hotel_Name_Hazlitt s                                                     int64
#  137   Hotel_Name_Henley House Hotel                                            int64
#  138   Hotel_Name_Henry VIII                                                    int64
#  139   Hotel_Name_Hilton London Angel Islington                                 int64
#  140   Hotel_Name_Hilton London Bankside                                        int64
#  141   Hotel_Name_Hilton London Canary Wharf                                    int64
#  142   Hotel_Name_Hilton London Euston                                          int64
#  143   Hotel_Name_Hilton London Green Park                                      int64
#  144   Hotel_Name_Hilton London Hyde Park                                       int64
#  145   Hotel_Name_Hilton London Kensington Hotel                                int64
#  146   Hotel_Name_Hilton London Metropole                                       int64
#  147   Hotel_Name_Hilton London Olympia                                         int64
#  148   Hotel_Name_Hilton London Paddington                                      int64
#  149   Hotel_Name_Hilton London Tower Bridge                                    int64
#  150   Hotel_Name_Hilton London Wembley                                         int64
#  151   Hotel_Name_Holiday Inn London Bloomsbury                                 int64
#  152   Hotel_Name_Holiday Inn London Brent Cross                                int64
#  153   Hotel_Name_Holiday Inn London Camden Lock                                int64
#  154   Hotel_Name_Holiday Inn London Kensington                                 int64
#  155   Hotel_Name_Holiday Inn London Kensington Forum                           int64
#  156   Hotel_Name_Holiday Inn London Mayfair                                    int64
#  157   Hotel_Name_Holiday Inn London Oxford Circus                              int64
#  158   Hotel_Name_Holiday Inn London Regent s Park                              int64
#  159   Hotel_Name_Holiday Inn London Stratford City                             int64
#  160   Hotel_Name_Holiday Inn London Wembley                                    int64
#  161   Hotel_Name_Holiday Inn London West                                       int64
#  162   Hotel_Name_Holiday Inn London Whitechapel                                int64
#  163   Hotel_Name_Hotel 55                                                      int64
#  164   Hotel_Name_Hotel 82 London                                               int64
#  165   Hotel_Name_Hotel Cafe Royal                                              int64
#  166   Hotel_Name_Hotel Cavendish                                               int64
#  167   Hotel_Name_Hotel Indigo London Kensington                                int64
#  168   Hotel_Name_Hotel Indigo London Paddington                                int64
#  169   Hotel_Name_Hotel Indigo London Tower Hill                                int64
#  170   Hotel_Name_Hotel La Place                                                int64
#  171   Hotel_Name_Hotel Moonlight                                               int64
#  172   Hotel_Name_Hotel Xanadu                                                  int64
#  173   Hotel_Name_Hotel Xenia Autograph Collection                              int64
#  174   Hotel_Name_Hotel du Vin Cannizaro House Wimbledon                        int64
#  175   Hotel_Name_Hyatt Regency London The Churchill                            int64
#  176   Hotel_Name_Innkeeper s Lodge London Greenwich                            int64
#  177   Hotel_Name_InterContinental London Park Lane                             int64
#  178   Hotel_Name_Intercontinental London The O2                                int64
#  179   Hotel_Name_Jumeirah Carlton Tower                                        int64
#  180   Hotel_Name_Jumeirah Lowndes Hotel                                        int64
#  181   Hotel_Name_K K Hotel George                                              int64
#  182   Hotel_Name_K West Hotel Spa                                              int64
#  183   Hotel_Name_Karma Sanctum Soho Hotel                                      int64
#  184   Hotel_Name_Kensington House Hotel                                        int64
#  185   Hotel_Name_Kingsway Hall Hotel                                           int64
#  186   Hotel_Name_Knightsbridge Hotel                                           int64
#  187   Hotel_Name_La Suite West Hyde Park                                       int64
#  188   Hotel_Name_Lancaster London                                              int64
#  189   Hotel_Name_Landmark London                                               int64
#  190   Hotel_Name_Lansbury Heritage Hotel                                       int64
#  191   Hotel_Name_Le Meridien Piccadilly                                        int64
#  192   Hotel_Name_London Bridge Hotel                                           int64
#  193   Hotel_Name_London City Suites                                            int64
#  194   Hotel_Name_London Elizabeth Hotel                                        int64
#  195   Hotel_Name_London Hilton on Park Lane                                    int64
#  196   Hotel_Name_London Marriott Hotel County Hall                             int64
#  197   Hotel_Name_London Marriott Hotel Grosvenor Square                        int64
#  198   Hotel_Name_London Marriott Hotel Kensington                              int64
#  199   Hotel_Name_London Marriott Hotel Marble Arch                             int64
#  200   Hotel_Name_London Marriott Hotel Park Lane                               int64
#  201   Hotel_Name_London Marriott Hotel Regents Park                            int64
#  202   Hotel_Name_London Marriott Hotel West India Quay                         int64
#  203   Hotel_Name_London Marriott Maida Vale                                    int64
#  204   Hotel_Name_London Suites                                                 int64
#  205   Hotel_Name_M by Montcalm Shoreditch London Tech City                     int64
#  206   Hotel_Name_ME London by Melia                                            int64
#  207   Hotel_Name_Malmaison London                                              int64
#  208   Hotel_Name_Mandarin Oriental Hyde Park London                            int64
#  209   Hotel_Name_Marlin Waterloo                                               int64
#  210   Hotel_Name_Mayflower Hotel Apartments                                    int64
#  211   Hotel_Name_Megaro Hotel                                                  int64
#  212   Hotel_Name_Melia White House Hotel                                       int64
#  213   Hotel_Name_Mercure London Bloomsbury Hotel                               int64
#  214   Hotel_Name_Mercure London Bridge                                         int64
#  215   Hotel_Name_Mercure London Hyde Park                                      int64
#  216   Hotel_Name_Mercure London Kensington Hotel                               int64
#  217   Hotel_Name_Mercure London Paddington Hotel                               int64
#  218   Hotel_Name_Milestone Hotel Kensington                                    int64
#  219   Hotel_Name_Millennium Copthorne Hotels at Chelsea Football Club          int64
#  220   Hotel_Name_Millennium Gloucester Hotel London                            int64
#  221   Hotel_Name_Millennium Hotel London Knightsbridge                         int64
#  222   Hotel_Name_Millennium Hotel London Mayfair                               int64
#  223   Hotel_Name_Mimi s Hotel Soho                                             int64
#  224   Hotel_Name_Mondrian London                                               int64
#  225   Hotel_Name_Montagu Place Hotel                                           int64
#  226   Hotel_Name_Montcalm Royal London House City of London                    int64
#  227   Hotel_Name_My Bloomsbury                                                 int64
#  228   Hotel_Name_My Chelsea                                                    int64
#  229   Hotel_Name_NH London Kensington                                          int64
#  230   Hotel_Name_New Linden Hotel                                              int64
#  231   Hotel_Name_Norfolk Towers Paddington                                     int64
#  232   Hotel_Name_Nottingham Place Hotel                                        int64
#  233   Hotel_Name_Novotel London Blackfriars                                    int64
#  234   Hotel_Name_Novotel London Canary Wharf                                   int64
#  235   Hotel_Name_Novotel London City South                                     int64
#  236   Hotel_Name_Novotel London Excel                                          int64
#  237   Hotel_Name_Novotel London Greenwich                                      int64
#  238   Hotel_Name_Novotel London Paddington                                     int64
#  239   Hotel_Name_Novotel London Tower Bridge                                   int64
#  240   Hotel_Name_Novotel London Waterloo                                       int64
#  241   Hotel_Name_Novotel London Wembley                                        int64
#  242   Hotel_Name_Novotel London West                                           int64
#  243   Hotel_Name_Number Sixteen                                                int64
#  244   Hotel_Name_Old Ship Inn Hackney                                          int64
#  245   Hotel_Name_One Aldwych                                                   int64
#  246   Hotel_Name_Paddington Court Executive Rooms                              int64
#  247   Hotel_Name_Park Avenue Baker Street                                      int64
#  248   Hotel_Name_Park Grand London Hyde Park                                   int64
#  249   Hotel_Name_Park Grand London Kensington                                  int64
#  250   Hotel_Name_Park Grand London Lancaster Gate                              int64
#  251   Hotel_Name_Park Grand Paddington Court                                   int64
#  252   Hotel_Name_Park International Hotel                                      int64
#  253   Hotel_Name_Park Lane Mews Hotel                                          int64
#  254   Hotel_Name_Park Plaza County Hall London                                 int64
#  255   Hotel_Name_Park Plaza London Park Royal                                  int64
#  256   Hotel_Name_Park Plaza London Riverbank                                   int64
#  257   Hotel_Name_Park Plaza London Waterloo                                    int64
#  258   Hotel_Name_Park Plaza Sherlock Holmes London                             int64
#  259   Hotel_Name_Park Plaza Victoria London                                    int64
#  260   Hotel_Name_Park Plaza Westminster Bridge London                          int64
#  261   Hotel_Name_Pestana Chelsea Bridge Hotel Spa                              int64
#  262   Hotel_Name_Portobello House                                              int64
#  263   Hotel_Name_Pullman London St Pancras                                     int64
#  264   Hotel_Name_Radisson Blu Edwardian Berkshire                              int64
#  265   Hotel_Name_Radisson Blu Edwardian Bloomsbury Street                      int64
#  266   Hotel_Name_Radisson Blu Edwardian Grafton                                int64
#  267   Hotel_Name_Radisson Blu Edwardian Hampshire                              int64
#  268   Hotel_Name_Radisson Blu Edwardian Kenilworth                             int64
#  269   Hotel_Name_Radisson Blu Edwardian Mercer Street                          int64
#  270   Hotel_Name_Radisson Blu Edwardian New Providence Wharf                   int64
#  271   Hotel_Name_Radisson Blu Edwardian Sussex                                 int64
#  272   Hotel_Name_Radisson Blu Edwardian Vanderbilt                             int64
#  273   Hotel_Name_Radisson Blu Portman Hotel London                             int64
#  274   Hotel_Name_Rafayel Hotel Spa                                             int64
#  275   Hotel_Name_Rathbone                                                      int64
#  276   Hotel_Name_Rocco Forte Brown s Hotel                                     int64
#  277   Hotel_Name_Rosewood London                                               int64
#  278   Hotel_Name_Royal Garden Hotel                                            int64
#  279   Hotel_Name_Rubens At The Palace                                          int64
#  280   Hotel_Name_Rydges Kensington Hotel                                       int64
#  281   Hotel_Name_Saint Georges Hotel                                           int64
#  282   Hotel_Name_San Domenico House                                            int64
#  283   Hotel_Name_Sanderson A Morgans Hotel                                     int64
#  284   Hotel_Name_Seraphine Kensington Gardens Hotel                            int64
#  285   Hotel_Name_Shaftesbury Hyde Park International                           int64
#  286   Hotel_Name_Shaftesbury Metropolis London Hyde Park                       int64
#  287   Hotel_Name_Shaftesbury Premier London Paddington                         int64
#  288   Hotel_Name_Shaftesbury Suites London Marble Arch                         int64
#  289   Hotel_Name_Shangri La Hotel at The Shard London                          int64
#  290   Hotel_Name_Shepherd s Bush Boutique Hotel                                int64
#  291   Hotel_Name_Sheraton Grand London Park Lane                               int64
#  292   Hotel_Name_Simply Rooms Suites                                           int64
#  293   Hotel_Name_Sloane Square Hotel                                           int64
#  294   Hotel_Name_Sofitel London St James                                       int64
#  295   Hotel_Name_South Place Hotel                                             int64
#  296   Hotel_Name_St Ermin s Hotel Autograph Collection                         int64
#  297   Hotel_Name_St George Hotel                                               int64
#  298   Hotel_Name_St George s Hotel Wembley                                     int64
#  299   Hotel_Name_St James Court A Taj Hotel London                             int64
#  300   Hotel_Name_St James Hotel Club Mayfair                                   int64
#  301   Hotel_Name_St Martins Lane A Morgans Original                            int64
#  302   Hotel_Name_St Pancras Renaissance Hotel London                           int64
#  303   Hotel_Name_St Paul s Hotel                                               int64
#  304   Hotel_Name_Staunton Hotel B B                                            int64
#  305   Hotel_Name_Staybridge Suites London Stratford                            int64
#  306   Hotel_Name_Staybridge Suites London Vauxhall                             int64
#  307   Hotel_Name_Strand Palace Hotel                                           int64
#  308   Hotel_Name_Sydney House Chelsea                                          int64
#  309   Hotel_Name_Taj 51 Buckingham Gate Suites and Residences                  int64
#  310   Hotel_Name_Ten Manchester Street Hotel                                   int64
#  311   Hotel_Name_The Abbey Court Notting Hill                                  int64
#  312   Hotel_Name_The Academy                                                   int64
#  313   Hotel_Name_The Ampersand Hotel                                           int64
#  314   Hotel_Name_The Arch London                                               int64
#  315   Hotel_Name_The Athenaeum                                                 int64
#  316   Hotel_Name_The Bailey s Hotel London                                     int64
#  317   Hotel_Name_The Beaufort                                                  int64
#  318   Hotel_Name_The Beaumont Hotel                                            int64
#  319   Hotel_Name_The Belgrave Hotel                                            int64
#  320   Hotel_Name_The Bloomsbury Hotel                                          int64
#  321   Hotel_Name_The Bryson Hotel                                              int64
#  322   Hotel_Name_The Capital                                                   int64
#  323   Hotel_Name_The Cavendish London                                          int64
#  324   Hotel_Name_The Chamberlain                                               int64
#  325   Hotel_Name_The Chelsea Harbour Hotel                                     int64
#  326   Hotel_Name_The Chesterfield Mayfair                                      int64
#  327   Hotel_Name_The Cleveland                                                 int64
#  328   Hotel_Name_The Colonnade                                                 int64
#  329   Hotel_Name_The Connaught                                                 int64
#  330   Hotel_Name_The Cranley Hotel                                             int64
#  331   Hotel_Name_The Cumberland A Guoman Hotel                                 int64
#  332   Hotel_Name_The Curtain                                                   int64
#  333   Hotel_Name_The Dorchester Dorchester Collection                          int64
#  334   Hotel_Name_The Drayton Court Hotel                                       int64
#  335   Hotel_Name_The Exhibitionist Hotel                                       int64
#  336   Hotel_Name_The Gore Hotel Starhotels Collezione                          int64
#  337   Hotel_Name_The Goring                                                    int64
#  338   Hotel_Name_The Grand at Trafalgar Square                                 int64
#  339   Hotel_Name_The Grosvenor                                                 int64
#  340   Hotel_Name_The Hari London                                               int64
#  341   Hotel_Name_The Henrietta Hotel                                           int64
#  342   Hotel_Name_The Hoxton Holborn                                            int64
#  343   Hotel_Name_The Hoxton Shoreditch                                         int64
#  344   Hotel_Name_The Justin James Hotel                                        int64
#  345   Hotel_Name_The Kensington Hotel                                          int64
#  346   Hotel_Name_The Kings Head Hotel                                          int64
#  347   Hotel_Name_The LaLit London                                              int64
#  348   Hotel_Name_The Lanesborough                                              int64
#  349   Hotel_Name_The Langham London                                            int64
#  350   Hotel_Name_The Laslett                                                   int64
#  351   Hotel_Name_The Leonard Hotel                                             int64
#  352   Hotel_Name_The Levin Hotel                                               int64
#  353   Hotel_Name_The Lodge Hotel Putney                                        int64
#  354   Hotel_Name_The London EDITION                                            int64
#  355   Hotel_Name_The Mandeville Hotel                                          int64
#  356   Hotel_Name_The Marble Arch London                                        int64
#  357   Hotel_Name_The Marylebone Hotel                                          int64
#  358   Hotel_Name_The May Fair Hotel                                            int64
#  359   Hotel_Name_The Montague On The Gardens                                   int64
#  360   Hotel_Name_The Montcalm At Brewery London City                           int64
#  361   Hotel_Name_The Montcalm Marble Arch                                      int64
#  362   Hotel_Name_The Nadler Kensington                                         int64
#  363   Hotel_Name_The Nadler Soho                                               int64
#  364   Hotel_Name_The Nadler Victoria                                           int64
#  365   Hotel_Name_The Ned                                                       int64
#  366   Hotel_Name_The Park City Grand Plaza Kensington Hotel                    int64
#  367   Hotel_Name_The Park Grand London Paddington                              int64
#  368   Hotel_Name_The Park Tower Knightsbridge a Luxury Collection Hotel        int64
#  369   Hotel_Name_The Pelham Starhotels Collezione                              int64
#  370   Hotel_Name_The Piccadilly London West End                                int64
#  371   Hotel_Name_The Pillar Hotel                                              int64
#  372   Hotel_Name_The Portobello Hotel                                          int64
#  373   Hotel_Name_The Premier Notting Hill                                      int64
#  374   Hotel_Name_The Principal London                                          int64
#  375   Hotel_Name_The Queens Gate Hotel                                         int64
#  376   Hotel_Name_The RE London Shoreditch                                      int64
#  377   Hotel_Name_The Rembrandt                                                 int64
#  378   Hotel_Name_The Ritz London                                               int64
#  379   Hotel_Name_The Rockwell                                                  int64
#  380   Hotel_Name_The Rookery                                                   int64
#  381   Hotel_Name_The Royal Horseguards                                         int64
#  382   Hotel_Name_The Royal Park Hotel                                          int64
#  383   Hotel_Name_The Savoy                                                     int64
#  384   Hotel_Name_The Soho Hotel                                                int64
#  385   Hotel_Name_The Stafford London                                           int64
#  386   Hotel_Name_The Sumner Hotel                                              int64
#  387   Hotel_Name_The Tophams Hotel                                             int64
#  388   Hotel_Name_The Tower A Guoman Hotel                                      int64
#  389   Hotel_Name_The Trafalgar Hilton                                          int64
#  390   Hotel_Name_The Victoria                                                  int64
#  391   Hotel_Name_The Waldorf Hilton                                            int64
#  392   Hotel_Name_The Wellesley Knightsbridge a Luxury Collection Hotel London  int64
#  393   Hotel_Name_The Westbourne Hyde Park                                      int64
#  394   Hotel_Name_The Westbridge Hotel                                          int64
#  395   Hotel_Name_The Westbury A Luxury Collection Hotel Mayfair London         int64
#  396   Hotel_Name_The Whitechapel                                               int64
#  397   Hotel_Name_The Zetter Hotel                                              int64
#  398   Hotel_Name_The Zetter Townhouse Clerkenwell                              int64
#  399   Hotel_Name_The Zetter Townhouse Marylebone                               int64
#  400   Hotel_Name_TheWesley                                                     int64
#  401   Hotel_Name_Thistle Euston                                                int64
#  402   Hotel_Name_Thistle Holborn The Kingsley                                  int64
#  403   Hotel_Name_Thistle Hyde Park                                             int64
#  404   Hotel_Name_Thistle Kensington Gardens                                    int64
#  405   Hotel_Name_Thistle Trafalgar Square The Royal Trafalgar                  int64
#  406   Hotel_Name_Threadneedles Autograph Collection                            int64
#  407   Hotel_Name_Twenty Nevern Square Hotel                                    int64
#  408   Hotel_Name_United Lodge Hotel and Apartments                             int64
#  409   Hotel_Name_W London Leicester Square                                     int64
#  410   Hotel_Name_W12 Rooms                                                     int64
#  411   Hotel_Name_Washington Mayfair Hotel                                      int64
#  412   Hotel_Name_Windermere Hotel                                              int64
#  413   Hotel_Name_citizenM London Bankside                                      int64
#  414   Hotel_Name_citizenM London Shoreditch                                    int64
#  415   Hotel_Name_citizenM Tower of London                                      int64
#  416   Hotel_Name_every hotel Piccadilly                                        int64
#  417   p_                                                                       int64
#  418   p_02                                                                     int64
#  419   p_1                                                                      int64
#  420   p_10                                                                     int64
#  421   p_100                                                                    int64
#  422   p_11                                                                     int64
#  423   p_12                                                                     int64
#  424   p_15                                                                     int64
#  425   p_1st                                                                    int64
#  426   p_2                                                                      int64
#  427   p_20                                                                     int64
#  428   p_24                                                                     int64
#  429   p_2nd                                                                    int64
#  430   p_3                                                                      int64
#  431   p_30                                                                     int64
#  432   p_4                                                                      int64
#  433   p_5                                                                      int64
#  434   p_50                                                                     int64
#  435   p_6                                                                      int64
#  436   p_7                                                                      int64
#  437   p_8                                                                      int64
#  438   p_able                                                                   int64
#  439   p_absolutely                                                             int64
#  440   p_access                                                                 int64
#  441   p_accessible                                                             int64
#  442   p_accommodate                                                            int64
#  443   p_accommodation                                                          int64
#  444   p_across                                                                 int64
#  445   p_actually                                                               int64
#  446   p_add                                                                    int64
#  447   p_adequate                                                               int64
#  448   p_afternoon                                                              int64
#  449   p_air                                                                    int64
#  450   p_aircon                                                                 int64
#  451   p_airport                                                                int64
#  452   p_airy                                                                   int64
#  453   p_albert                                                                 int64
#  454   p_allocate                                                               int64
#  455   p_allow                                                                  int64
#  456   p_almost                                                                 int64
#  457   p_along                                                                  int64
#  458   p_already                                                                int64
#  459   p_also                                                                   int64
#  460   p_although                                                               int64
#  461   p_always                                                                 int64
#  462   p_amaze                                                                  int64
#  463   p_amazingly                                                              int64
#  464   p_ambiance                                                               int64
#  465   p_ambience                                                               int64
#  466   p_amenity                                                                int64
#  467   p_anniversary                                                            int64
#  468   p_another                                                                int64
#  469   p_anyone                                                                 int64
#  470   p_anything                                                               int64
#  471   p_anywhere                                                               int64
#  472   p_apart                                                                  int64
#  473   p_apartment                                                              int64
#  474   p_apollo                                                                 int64
#  475   p_apologetic                                                             int64
#  476   p_appear                                                                 int64
#  477   p_appoint                                                                int64
#  478   p_appreciate                                                             int64
#  479   p_approachable                                                           int64
#  480   p_area                                                                   int64
#  481   p_arena                                                                  int64
#  482   p_around                                                                 int64
#  483   p_arrange                                                                int64
#  484   p_arrival                                                                int64
#  485   p_arrive                                                                 int64
#  486   p_ask                                                                    int64
#  487   p_aspect                                                                 int64
#  488   p_atmosphere                                                             int64
#  489   p_attend                                                                 int64
#  490   p_attention                                                              int64
#  491   p_attentive                                                              int64
#  492   p_attitude                                                               int64
#  493   p_attraction                                                             int64
#  494   p_attractive                                                             int64
#  495   p_available                                                              int64
#  496   p_away                                                                   int64
#  497   p_awesome                                                                int64
#  498   p_awful                                                                  int64
#  499   p_baby                                                                   int64
#  500   p_back                                                                   int64
#  501   p_bad                                                                    int64
#  502   p_bag                                                                    int64
#  503   p_balcony                                                                int64
#  504   p_balloon                                                                int64
#  505   p_bank                                                                   int64
#  506   p_bar                                                                    int64
#  507   p_barbican                                                               int64
#  508   p_base                                                                   int64
#  509   p_basement                                                               int64
#  510   p_basic                                                                  int64
#  511   p_bath                                                                   int64
#  512   p_bathroom                                                               int64
#  513   p_beautiful                                                              int64
#  514   p_beautifully                                                            int64
#  515   p_bed                                                                    int64
#  516   p_bedroom                                                                int64
#  517   p_behind                                                                 int64
#  518   p_believe                                                                int64
#  519   p_ben                                                                    int64
#  520   p_best                                                                   int64
#  521   p_beyond                                                                 int64
#  522   p_big                                                                    int64
#  523   p_birthday                                                               int64
#  524   p_biscuit                                                                int64
#  525   p_bite                                                                   int64
#  526   p_black                                                                  int64
#  527   p_blind                                                                  int64
#  528   p_board                                                                  int64
#  529   p_boat                                                                   int64
#  530   p_bonus                                                                  int64
#  531   p_book                                                                   int64
#  532   p_bottle                                                                 int64
#  533   p_boutique                                                               int64
#  534   p_box                                                                    int64
#  535   p_boyfriend                                                              int64
#  536   p_brand                                                                  int64
#  537   p_break                                                                  int64
#  538   p_breakfast                                                              int64
#  539   p_bridge                                                                 int64
#  540   p_bright                                                                 int64
#  541   p_brilliant                                                              int64
# ...
#  2563  n_sugar                                                                  int64
#  2564  n_suggest                                                                int64
#  2565  n_suit                                                                   int64
#  2566  n_suitable                                                               int64
#  2567  n_suitcase                                                               int64
#  2568  n_suite                                                                  int64
#  2569  n_sunday                                                                 int64
#  2570  n_super                                                                  int64
#  2571  n_superb                                                                 int64
#  2572  n_superior                                                               int64
#  2573  n_supply                                                                 int64
#  2574  n_suppose                                                                int64
#  2575  n_sure                                                                   int64
#  2576  n_surly                                                                  int64
#  2577  n_surprise                                                               int64
#  2578  n_surround                                                               int64
#  2579  n_swim                                                                   int64
#  2580  n_switch                                                                 int64
#  2581  n_system                                                                 int64
#  2582  n_table                                                                  int64
#  2583  n_take                                                                   int64
#  2584  n_talk                                                                   int64
#  2585  n_tall                                                                   int64
#  2586  n_tap                                                                    int64
#  2587  n_taste                                                                  int64
#  2588  n_tatty                                                                  int64
#  2589  n_taxi                                                                   int64
#  2590  n_tea                                                                    int64
#  2591  n_teabags                                                                int64
#  2592  n_team                                                                   int64
#  2593  n_telephone                                                              int64
#  2594  n_television                                                             int64
#  2595  n_tell                                                                   int64
#  2596  n_temp                                                                   int64
#  2597  n_temperature                                                            int64
#  2598  n_term                                                                   int64
#  2599  n_terrace                                                                int64
#  2600  n_terrible                                                               int64
#  2601  n_thank                                                                  int64
#  2602  n_therefore                                                              int64
#  2603  n_thermostat                                                             int64
#  2604  n_thick                                                                  int64
#  2605  n_thin                                                                   int64
#  2606  n_thing                                                                  int64
#  2607  n_think                                                                  int64
#  2608  n_third                                                                  int64
#  2609  n_though                                                                 int64
#  2610  n_three                                                                  int64
#  2611  n_throughout                                                             int64
#  2612  n_ticket                                                                 int64
#  2613  n_tight                                                                  int64
#  2614  n_tile                                                                   int64
#  2615  n_till                                                                   int64
#  2616  n_time                                                                   int64
#  2617  n_tiny                                                                   int64
#  2618  n_tip                                                                    int64
#  2619  n_tire                                                                   int64
#  2620  n_toast                                                                  int64
#  2621  n_toaster                                                                int64
#  2622  n_together                                                               int64
#  2623  n_toilet                                                                 int64
#  2624  n_toiletry                                                               int64
#  2625  n_top                                                                    int64
#  2626  n_total                                                                  int64
#  2627  n_totally                                                                int64
#  2628  n_touch                                                                  int64
#  2629  n_towel                                                                  int64
#  2630  n_traffic                                                                int64
#  2631  n_train                                                                  int64
#  2632  n_travel                                                                 int64
#  2633  n_traveller                                                              int64
#  2634  n_tray                                                                   int64
#  2635  n_treat                                                                  int64
#  2636  n_tree                                                                   int64
#  2637  n_tricky                                                                 int64
#  2638  n_trip                                                                   int64
#  2639  n_trouble                                                                int64
#  2640  n_try                                                                    int64
#  2641  n_tub                                                                    int64
#  2642  n_tube                                                                   int64
#  2643  n_turn                                                                   int64
#  2644  n_tv                                                                     int64
#  2645  n_twice                                                                  int64
#  2646  n_twin                                                                   int64
#  2647  n_two                                                                    int64
#  2648  n_type                                                                   int64
#  2649  n_u                                                                      int64
#  2650  n_unable                                                                 int64
#  2651  n_unacceptable                                                           int64
#  2652  n_uncomfortable                                                          int64
#  2653  n_underground                                                            int64
#  2654  n_understaffed                                                           int64
#  2655  n_understand                                                             int64
#  2656  n_unfortunately                                                          int64
#  2657  n_unfriendly                                                             int64
#  2658  n_unhelpful                                                              int64
#  2659  n_unit                                                                   int64
#  2660  n_unless                                                                 int64
#  2661  n_unpleasant                                                             int64
#  2662  n_update                                                                 int64
#  2663  n_upgrade                                                                int64
#  2664  n_upon                                                                   int64
#  2665  n_upset                                                                  int64
#  2666  n_upstairs                                                               int64
#  2667  n_use                                                                    int64
#  2668  n_useless                                                                int64
#  2669  n_usual                                                                  int64
#  2670  n_usually                                                                int64
#  2671  n_v                                                                      int64
#  2672  n_value                                                                  int64
#  2673  n_variety                                                                int64
#  2674  n_various                                                                int64
#  2675  n_vegetarian                                                             int64
#  2676  n_vent                                                                   int64
#  2677  n_ventilation                                                            int64
#  2678  n_via                                                                    int64
#  2679  n_view                                                                   int64
#  2680  n_visit                                                                  int64
#  2681  n_voucher                                                                int64
#  2682  n_wait                                                                   int64
#  2683  n_waiter                                                                 int64
#  2684  n_waitress                                                               int64
#  2685  n_wake                                                                   int64
#  2686  n_walk                                                                   int64
#  2687  n_wall                                                                   int64
#  2688  n_wallpaper                                                              int64
#  2689  n_want                                                                   int64
#  2690  n_wardrobe                                                               int64
#  2691  n_warm                                                                   int64
#  2692  n_warn                                                                   int64
#  2693  n_wash                                                                   int64
#  2694  n_wasnt                                                                  int64
#  2695  n_waste                                                                  int64
#  2696  n_watch                                                                  int64
#  2697  n_water                                                                  int64
#  2698  n_way                                                                    int64
#  2699  n_weak                                                                   int64
#  2700  n_wear                                                                   int64
#  2701  n_weather                                                                int64
#  2702  n_web                                                                    int64
#  2703  n_website                                                                int64
#  2704  n_wed                                                                    int64
#  2705  n_week                                                                   int64
#  2706  n_weekend                                                                int64
#  2707  n_weird                                                                  int64
#  2708  n_welcome                                                                int64
#  2709  n_well                                                                   int64
#  2710  n_west                                                                   int64
#  2711  n_wet                                                                    int64
#  2712  n_whatsoever                                                             int64
#  2713  n_whether                                                                int64
#  2714  n_whilst                                                                 int64
#  2715  n_white                                                                  int64
#  2716  n_whole                                                                  int64
#  2717  n_wi                                                                     int64
#  2718  n_wide                                                                   int64
#  2719  n_wife                                                                   int64
#  2720  n_wifi                                                                   int64
#  2721  n_window                                                                 int64
#  2722  n_wine                                                                   int64
#  2723  n_wish                                                                   int64
#  2724  n_within                                                                 int64
#  2725  n_without                                                                int64
#  2726  n_woman                                                                  int64
#  2727  n_wonder                                                                 int64
#  2728  n_wonderful                                                              int64
#  2729  n_wood                                                                   int64
#  2730  n_wooden                                                                 int64
#  2731  n_word                                                                   int64
#  2732  n_work                                                                   int64
#  2733  n_world                                                                  int64
#  2734  n_worry                                                                  int64
#  2735  n_worth                                                                  int64
#  2736  n_would                                                                  int64
#  2737  n_write                                                                  int64
#  2738  n_wrong                                                                  int64
#  2739  n_year                                                                   int64
#  2740  n_yes                                                                    int64
#  2741  n_yet                                                                    int64
#  2742  n_young                                                                  int64
#  2743  rating                                                                   int64
# dtypes: float64(3), int64(2741)
# memory usage: 89.3 MB

# %%
# Check hoy many columns are related to hotel names, positive review words, and negative review words

# Set up the column prefixes to count and a counter
regex_list = ['^Hotel_Name_', '^p_', '^n_']
dummy_col = 0 

# check the list of columns for the prefixes counts and print the results 

for i in regex_list:
    r = re.compile(i)
    temp_list = list(filter(r.match,test_df.columns))
    dummy_col += len(temp_list)
    print(f'There are {len(temp_list)} columns that start with {i}')

print(f'There are {test_df.shape[1] - dummy_col} other columns')
# Out:
# There are 396 columns that start with ^Hotel_Name_
# There are 983 columns that start with ^p_
# There are 1343 columns that start with ^n_
# There are 22 other columns

# %%
#next step is to set up x/y test and train DFs
X_train = train_df.drop('rating', axis=1)
X_test = test_df.drop('rating', axis=1)
y_train = train_df['rating']
y_test = test_df['rating']

# %%
print(f'Test data set shape: {test_df.shape[0]} rows {test_df.shape[1]} columns')
print(f'Train data set shape: {train_df.shape[0]} rows {train_df.shape[1]} columns')
print(f'X_train shape: {X_train.shape}\nX_test shape: {X_test.shape}\
        \ny_train shape: {y_train.shape}\ny_test shape: {y_test.shape}')
# Out:
# Test data set shape: 4267 rows 2744 columns
# Train data set shape: 12798 rows 2744 columns
# X_train shape: (12798, 2743)
# X_test shape: (4267, 2743)
# y_train shape: (12798,)
# y_test shape: (4267,)

# %% [markdown]
# The updated data set contains about 17,000 rows with 25% of them being reserved for testing models. There are 2744 columns which is a huge expansion to the feature set. To get an understanding of what all those columns were I looked at the `.info()` listing and noticed that many columns from the original set are present. The expansion was from encoding tags, hotel names, positive review keywords and negative review key words. Using regular expressions I was able to find that there are approx.:  400 Hotels, 1000 positive review keywords, and 1350 negative review keywords.
#
# The final step of preparation was to create X and y dataframes from the test and train data files. As directed, 'Rating' was separated as a target variable.

# %% [markdown]
# ## 1 Employ a Linear Classifer on this dataset
#
# a. Fit a logisitic regression model to this data with the solver set to lbfgs. What is the accuracy score on the test set?
#
# b. What are the 20 words most predictive of a good review (from the positive review column)? What are the 20 words most predictive with a bad review (from the negative review column)? Use the regression coefficients to answer this question
#
# c. Reduce the dimensionality of the dataset using PCA, what is the relationship between the number of dimensions and run-time for a logistic regression?
#
# d. List one advantage and one disadvantage of dimensionality reduction.

# %% [markdown]
# ### 1 a.
#
# Setting up a basic model yielded a result of 73.3% accuracy. I added the `max_iter` parameter to ensure the logsitic regression would coverge. With so many variables scaling did not help the model coverge in the standard 100 iterations. I got good results after 250 iterations, but other versions of this model take more so I went with 1,000.

# %%
# create scaled versions of the test and train dataframes

scaler = StandardScaler()
scaler = scaler.fit(X_train)
X_train_ss = scaler.transform(X_train)
X_test_ss = scaler.transform(X_test)

# %%
# instantiate the model
# use lbfgs solver as directed, 1000 iterations to ensure the model converges
logistic_regression_model = LogisticRegression(solver='lbfgs', max_iter=1000)

# fit the model
logistic_regression_model.fit(X_train_ss, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
# Calculate the score and display it

score = logistic_regression_model.score(X_test_ss,y_test)
print(f'The score on the test set is {score*100:.1f}%')
# Out:
# The score on the test set is 73.3%

# %% [markdown]
# ### 1 b.
#
# Now that I have the the fitted model I can extract the list of coefficients and columns they are associated with. Taking a look at the lists and associated coefficients I can see that positive words tend to more impact on the model.

# %%
# Set up a dataframe consisting of the coefficient of the model and the list of columns 

coefficient_df  = pd.DataFrame(logistic_regression_model.coef_).T
cols = pd.DataFrame(X_test.columns)

coefficient_df = pd.concat([coefficient_df,cols], axis = 1)
coefficient_df.set_axis(['coef','column'], axis=1, inplace=True)

# create smaller dataframes consisting of just positive review words and negative review words

p_df = coefficient_df[coefficient_df['column'].str.startswith('p_')]
n_df = coefficient_df[coefficient_df['column'].str.startswith('n_')]

# sort these columns and display top 20 words by coefficient.  
print('Top 20 p_words: ')
display(p_df.sort_values('coef', ascending=False).head(20))

print('Top 20 n_words: ')
display(n_df.sort_values('coef', ascending=False).head(20))
# Out:
# Top 20 p_words:
#           coef         column
# 812   0.544474         p_gift
# 733   0.517316    p_excellent
# 880   0.450513   p_incredible
# 731   0.401304       p_exceed
# 874   0.398645   p_impeccable
# 728   0.374315   p_everything
# 829   0.350164         p_hair
# 822   0.348846        p_great
# 1242  0.348544        p_staff
# 664   0.337498       p_deluxe
# 483   0.330745      p_arrange
# 1232  0.328158      p_special
# 636   0.323876        p_could
# 735   0.319166  p_exceptional
# 463   0.315992    p_amazingly
# 458   0.307155      p_already
# 755   0.303737    p_fantastic
# 1062  0.299881      p_perfect
# 462   0.296349        p_amaze
# 539   0.291948       p_bridge
# Top 20 n_words:
#           coef       column
# 2027  0.706545        n_inn
# 2208  0.360512    n_nothing
# 1980  0.351926     n_height
# 2637  0.341929     n_tricky
# 1725  0.326120  n_criticism
# 2728  0.315765  n_wonderful
# 1521  0.249176     n_assume
# 1678  0.241560   n_complain
# 2042  0.238234       n_join
# 1799  0.220748     n_drawer
# 2489  0.217813     n_slight
# 1782  0.214562    n_dislike
# 2272  0.214130       n_pick
# 1964  0.213995       n_half
# 1907  0.210130     n_follow
# 2189  0.207238   n_negative
# 1853  0.193955  n_executive
# 2423  0.187800     n_sachet
# 2086  0.187543     n_little
# 1438  0.187366        n_5th

# %% [markdown]
# ### 1 c.
#
# Using PCA and reducing the number of dimenensions did improve the model by 3%. This is an improvement of the first model, however there is still work to do.
#
# Using `%timeit` I can see there is an order of magnitude difference between fitting a model to the full PCA set vs the 6 dimension set.

# %%
# create PCA object
log_PCA = PCA()

# fit PCA to our data
log_PCA.fit(X_train_ss)

# transform the train and test data
X_train_ss_PCA = log_PCA.transform(X_train_ss)
X_test_ss_PCA = log_PCA.transform(X_test_ss)

# %%
# look at the shape of the PCA data
X_train_ss_PCA.shape
# Out:
# (12798, 2743)

# %%
# look at the variance explained by the first 10 most impactful features
for i in range(10):
    print(f'PCA feature #{i+1} var ratio: {log_PCA.explained_variance_ratio_[i]}')

# look at the variance explained by the last 10 most impactful features
for i in range(10):
    print(f'PCA feature #{-i} var ratio: {log_PCA.explained_variance_ratio_[-i]}')

# with over 2000 features it it makes sense that less each contributes < 1%
# Out:
# PCA feature #1 var ratio: 0.007637859215482228
# PCA feature #2 var ratio: 0.004727197738142273
# PCA feature #3 var ratio: 0.0021802390151672534
# PCA feature #4 var ratio: 0.001960084867135508
# PCA feature #5 var ratio: 0.0019249941981280033
# PCA feature #6 var ratio: 0.0017158766635731037
# PCA feature #7 var ratio: 0.0016899621491484448
# PCA feature #8 var ratio: 0.0016589648703314523
# PCA feature #9 var ratio: 0.0016107487339177213
# PCA feature #10 var ratio: 0.001576439059399313
# PCA feature #0 var ratio: 0.007637859215482228
# PCA feature #-1 var ratio: 5.691169061098283e-37
# PCA feature #-2 var ratio: 1.6093837478622824e-36
# PCA feature #-3 var ratio: 3.132638814409508e-36
# PCA feature #-4 var ratio: 4.432006586156138e-36
# PCA feature #-5 var ratio: 6.248977796351376e-36
# PCA feature #-6 var ratio: 1.3445946980485758e-35
# PCA feature #-7 var ratio: 1.6918929449174655e-35
# PCA feature #-8 var ratio: 1.8554423987425492e-35
# PCA feature #-9 var ratio: 1.9447051737277108e-35

# %%
# look for a good number of PCs
plt.figure()
plt.plot(log_PCA.explained_variance_ratio_)
plt.show()

#the elbow is really close to 0 let's make another plot with 100 pts

# %%
plt.figure()
plt.plot(log_PCA.explained_variance_ratio_[0:99])
plt.show()

#the elbow is less than 20, enhance!

# %%
plt.figure()
plt.plot(range(1,21),log_PCA.explained_variance_ratio_[0:20])
plt.xticks(range(1,20,1))
plt.show()

#This indicates the I should use 6 components

# %%
# fit the data using a 6 component PCA object

log_PCA_6 = PCA(n_components=6)
log_PCA_6.fit(X_train_ss)

# transform the train and test data
X_train_ss_PCA_6 = log_PCA_6.transform(X_train_ss)
X_test_ss_PCA_6 = log_PCA_6.transform(X_test_ss)

# %%
# build a logsitic regression model to this data

my_logreg_PCA_6 = LogisticRegression(solver='lbfgs', max_iter=1000)
my_logreg_PCA_6.fit(X_train_ss_PCA_6,y_train)
my_logreg_PCA_6.score(X_test_ss_PCA_6,y_test)

# we picked up 3%
# Out:
# 0.7630653855167565

# %%
# %%timeit
my_logreg_PCA_6.fit(X_train_ss_PCA_6,y_train)
# Out:
# 7.94 ms ± 87.8 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
my_logreg_PCA = LogisticRegression(solver='lbfgs',max_iter=1000)

# %%
# %%timeit
my_logreg_PCA.fit(X_train_ss_PCA,y_train)
# Out:
# 7.37 s ± 293 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# ### 1.d
#
# One advantage of using PCA is you can reduce the number of features in your dataset without losing information. This saves time training your models without a loss of infromation supplied to them. In this case reducing the dimensions along with PCA imrpoved the accuracy score.
#
# The disadvantage is in understanding and interpreting the results. Once the data is transformed using PCA the features are combined so it is difficult to tell which ones are impacting results. This might be okay if you a trying to opitimize performnace of a model rather than using a model to explain which features impact the results.

# %% [markdown]
# ## 2 Employ a K- Nearest Neighbor classifier on the dataset.
#
# Fit a KNN model to this data. What is the accuracy score on the test set?
#
# KNN is a computationally expensive model. Reduce the number of observations (data points) in the dataset. What is the relationship between the number of observations and run-time for KNN?
#
# List one advantage and one disadvantage of reducing the number of observations.
#
# Use the dataset to find an optimal value for K in the KNN algorithm. You will need to split your dataset into train and validation sets.
#
# What is the issue with splitting the data into train and validation sets after performing vectorization?

# %% [markdown]
# ### 2 a
#
# Running the test of scaled data yielded a score of 57%

# %%
# fit a KNN model and find the accuract score

KNN_NLP = KNeighborsClassifier()
KNN_NLP.fit(X_train_ss, y_train)

KNN_test = KNN_NLP.predict(X_test)
KNN_accuracy = accuracy_score(KNN_test, y_test)
# Out:
# c:\Users\russk\anaconda3\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(

# %%
print(KNN_accuracy)
# Out:
# 0.5753456761190532

# %% [markdown]
# ### 2b 2c
#
# Reducing the number of obervations in the model leads to a faster run time. This weakens the model by increasting the chance you will create an overfitted model that will perform worse overall

# %%
X_train_reduced, X_test_reduced, y_train_reduced, y_test_reduced = train_test_split(X_train, y_train, test_size=0.8, random_state=1)

# %%
## all data 454 ms/loop
## 80% data 348 ms/loop
## 60% data 256 ms/loop
## 40% data 189 ms/loop
## 20% data 87 ms/loop

## reducing the number of obervations in the model leads to a faster run time. This weakens the model by increasting the chance you will create an overfitted model that will perform worse overall

# %%
# %%timeit
KNN_NLP.fit(X_train_reduced, y_train_reduced)
# Out:
# 87.7 ms ± 2.24 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# ### 2d
#
# 18 nearest neighbors would be the optimal paramater for this model.
#
# ### 2e
# Spliting data into test/train/validation sets before vectorizing raises the potential of creating different features in each set. The result will be models that are overfitted to the training set.

# %%
k_list =np.arange(1,50,1)
score_list = []

X_train_knn, X_validiation_knn, y_train_knn, y_validiation_knn = train_test_split(X_train_ss, y_train, test_size=0.2, random_state=1)

for k in k_list:
    KNN_NLP = KNeighborsClassifier(n_neighbors=k)
    KNN_NLP.fit(X_train_knn, y_train_knn)
    KNN_test = KNN_NLP.predict(X_validiation_knn)
    KNN_accuracy = accuracy_score(KNN_test, y_validiation_knn)
    score_list.append(KNN_accuracy)

# %%
plt.figure(figsize=(15,10))
plt.plot(k_list, score_list, marker='|')
plt.show()

# %% [markdown]
# ## 3 Employ a Decision Tree classifier on this dataset
#
#
# Employ a Decision Tree classifier on this dataset:
#
# Fit a decision tree model to this data. What is the accuracy score on the test set?
#
# Use the data set (or a subsample) to find an optimal value for the maximum depth of the decision tree. You will need to split your data set into train and validation.
#
# Provide two advantages of decision trees over KNN. Provide two weaknesses of decision trees (classification or regression trees)

# %% [markdown]
# ### 3a
#
# The base model for decision tree yielded a 69.7% result

# %%
DT_model = DecisionTreeClassifier()
DT_model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
DT_model.score(X_test, y_test)
# Out:
# 0.6972111553784861

# %% [markdown]
# ### 3b
#
# The optimal depth for a the decision tree on this dataset is 8. That yields a 74% accuracy rate on the validation set and a 74.5% on the test data.

# %%
depth_list = np.arange(1,26)
score_list = []

X_train_DT, X_validiation_DT, y_train_DT, y_validiation_DT = train_test_split(X_train, y_train, test_size=0.2, random_state=1)


for d in depth_list:
    DT_model = DecisionTreeClassifier(max_depth=d)
    DT_model.fit(X_train_DT, y_train_DT)
    DT_score = DT_model.score(X_validiation_DT,y_validiation_DT)
    score_list.append(DT_score)
    
print('Process Complete')

plt.figure(figsize=(15,10))
plt.plot(depth_list, score_list, marker='+')
plt.show()

results = pd.DataFrame([depth_list,score_list]).T
# Out:
# Process Complete

# %%
results = pd.DataFrame([depth_list,score_list]).T

results.sort_values(by=1, ascending=False).head(1)
# Out:
#      0         1
# 7  8.0  0.741406

# %%
DT_model = DecisionTreeClassifier(max_depth=8)
DT_model.fit(X_train,y_train)
DT_model.score(X_test, y_test)
# Out:
# 0.7457229903913757

# %% [markdown]
# ## 4
#
# What is the purpose of the validation set, i.e., how is it different than the test set?
#
# The validation sets are used for tuning a model. It is a subset of the training data where test data is separated before the training process. By keeping validation data separate from training data we can tune the model without bringing in bias from the test set. It also ensures that the test data is unseen by the model (and the data scientist!) This is strengthend with cross validation is used since there are multiple samples of the training data being tested.

# %% [markdown]
# ## 5
#
#
# Re-run a decision tree or logistic regression on the data again:
#
# Perform a 5-fold cross validation to optimize the hyperparameters of your model.
#  What does your confusion matrix look like for your best model on the test set?

# %% [markdown]
# ### 5 a
#
# Using a 5-fold cross validation on the logisitic regression model pointed to 0.001 being the optimal value for the l2 parameter C.

# %%
cv_score_list = []
C_range = [.00001,.0001,.001,.1,1,10,100,1000,10000]

for c in C_range:
    log_model_5 = LogisticRegression(solver='lbfgs', max_iter=1000, penalty='l2', C=c)

    score = np.mean(cross_val_score(log_model_5,X_train_ss,y_train, cv=5))

    cv_score_list.append(score)

    print(f'{c} loop complete')
# Out:
# 1e-05 loop complete
# 0.0001 loop complete
# 0.001 loop complete
# 0.1 loop complete
# 1 loop complete
# 10 loop complete
# 100 loop complete
# 1000 loop complete
# 10000 loop complete

# %%
plt.figure()
plt.plot(C_range, cv_score_list, marker='|')
plt.xscale("log")
plt.title('parametter tuning for C')
plt.xlabel('L2 Regularization Parameter C')
plt.ylabel('Cross Validation Score')
plt.show()

# %%
results = pd.DataFrame([C_range,cv_score_list]).T
results.sort_values(by=1, ascending=False).head(1)
# Out:
#        0         1
# 2  0.001  0.775277

# %%
log_model_5b = LogisticRegression(solver='lbfgs', max_iter=250, penalty='l2', C=.001)
log_model_5b.fit(X_train_ss, y_train)
# Out:
# LogisticRegression(C=0.001, max_iter=250)

# %% [markdown]
# ### 5b
#
# This model, now tuned, has an acurracy of 78% making it the best version of the regression model yet. The confusion matrix shows about 1300 bad reviews correctly labeled and 2000 good reviews correctly labeled. What's interesting is that the number of of false positives and false negatives are similar and the model isn't tedning to misclassify in one direction or the other. To me that indicates that our model isn't biased because the edge cases are evenly split.

# %%
plot_confusion_matrix(log_model_5b, X_test_ss, y_test)
# Out:
# c:\Users\russk\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
# other metrics

log_model_5b_predictions = log_model_5b.predict(X_test_ss)
report_initial = classification_report(y_test, log_model_5b_predictions)
print(report_initial)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.71      0.73      1809
#            1       0.80      0.82      0.81      2458
#
#     accuracy                           0.78      4267
#    macro avg       0.77      0.77      0.77      4267
# weighted avg       0.78      0.78      0.78      4267

# %% [markdown]
# ## 6 Create a Feature of your choice
#
# Explain your new feature and why you consider it will improve accuracy.
#
# Run the model from question 5 again. You will have to re-optimize your hyperparameters. Has the accuracy score of your best model improved on the test set after adding the new feature you created?
#
# ### 6a
#
# I used the month column to create the feature 'season'. Travel tends to occur seasonaly and grouping similar months together could lead seasonal trends coming out.
#
# ### 6b
#
# This feature really did not imporve the model. Taking a closer look, the time data is on the date of the review, not the date of the stay. This makes the date's inclusion questionable in general.
#
# Other features worth exploring would induding making categories of long and short reviews based on the number of words submitted. It might also be possible to use the location data to see if the country or region had an impact on a rating.

# %%
X_train['month_of_review'].value_counts().sort_index()
# Out:
# 1     1105
# 2     1192
# 3     1192
# 4     1095
# 5     1049
# 6     1011
# 7     1030
# 8     1097
# 9      924
# 10     992
# 11     965
# 12    1146
# Name: month_of_review, dtype: int64

# %%
X_train_6 = X_train.copy()
X_train_6['season'] = X_train_6['month_of_review'].map({
    12:1,
    1:1,
    2:1,
    3:2,
    4:2,
    5:2,
    6:3,
    7:3,
    8:3,
    9:4,
    10:4,
    11:4,
})
X_train_6['season'].value_counts()
# Out:
# 1    3443
# 2    3336
# 3    3138
# 4    2881
# Name: season, dtype: int64

# %%
X_test_6 = X_test.copy()
X_test_6['season'] = X_test_6['month_of_review'].map({
    12:1,
    1:1,
    2:1,
    3:2,
    4:2,
    5:2,
    6:3,
    7:3,
    8:3,
    9:4,
    10:4,
    11:4,
})
X_test_6['season'].value_counts()
# Out:
# 1    1182
# 2    1104
# 3    1043
# 4     938
# Name: season, dtype: int64

# %%
X_train_6.drop(columns='month_of_review', inplace=True)
X_test_6.drop(columns='month_of_review',inplace=True)

# %%
scaler = StandardScaler()
scaler = scaler.fit(X_train_6)
X_train_ss_6 = scaler.transform(X_train_6)
X_test_ss_6 = scaler.transform(X_test_6)

# %%
cv_score_list = []
C_range = [.00001,.0001,.001,.1,1,10]

for c in C_range:
    log_model_6 = LogisticRegression(solver='lbfgs', max_iter=1000, penalty='l2', C=c)

    score = np.mean(cross_val_score(log_model_6,X_train_ss_6,y_train, cv=5))

    cv_score_list.append(score)

    print(f'{c} loop complete')
# Out:
# 1e-05 loop complete
# 0.0001 loop complete
# 0.001 loop complete
# 0.1 loop complete
# 1 loop complete
# 10 loop complete

# %%
plt.figure()
plt.plot(C_range, cv_score_list, marker='|')
plt.xscale("log")
plt.title('parametter tuning for C')

plt.xlabel('L2 Regularization Parameter C')
plt.ylabel('Cross Validation Score')
plt.show()

results = pd.DataFrame([C_range,cv_score_list]).T

results.sort_values(by=1, ascending=False).head(1)
# Out:
#        0        1
# 2  0.001  0.77559

# %%
log_model_6 = LogisticRegression(solver='lbfgs', max_iter=500, penalty='l2', C=.001)

log_model_6.fit(X_train_ss_6, y_train)
# Out:
# LogisticRegression(C=0.001, max_iter=500)

# %%
plot_confusion_matrix(log_model_6, X_test_ss_6, y_test)
# Out:
# c:\Users\russk\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
log_model_6_predictions = log_model_6.predict(X_test_ss_6)

# %%
report_initial = classification_report(y_test, log_model_6_predictions)
print(report_initial)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.71      0.73      1809
#            1       0.80      0.82      0.81      2458
#
#     accuracy                           0.78      4267
#    macro avg       0.77      0.77      0.77      4267
# weighted avg       0.78      0.78      0.78      4267
